# %%
example_dict  = {
    "name": "Alice",
    "age": 30,
    "city": "New York",
    "is_student": False,
    "courses": ["Math", "Science", "History"],
    "address": {
        "street": "123 Main St",
        "zip_code": "10001"
    }}

import pandas as pd

df = pd.DataFrame.from_dict([example_dict], orient='columns')
df.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 14
#       1 example_dict  = {
#       2     "name": "Alice",
#       3     "age": 30,
#    (...)
#       9         "zip_code": "10001"
#      10     }}
#      12 import pandas as pd
# ---> 14 df = pd.DataFrame.from_dict([example_dict], orient='columns', index=False)
#      15 df.head()
#
# TypeError: from_dict() got an unexpected keyword argument 'index'
