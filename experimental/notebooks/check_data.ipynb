# %%
import os
import pandas as pd


notebook_path = os.getcwd()
experiment_path = os.path.join(os.path.dirname(notebook_path))
data_dir = os.path.join(os.path.dirname(experiment_path), 'f1_predictor/data')
training_data_path = os.path.join(data_dir, 'train_data.csv')
training_data = pd.read_csv(training_data_path)
print(training_data[training_data['finishing_position'] == 0])
# Out:
# Empty DataFrame
# Columns: [race_id, driver_id, lap, normalized_lap, average_normalized_lap, lap_progress, current_position_norm, finishing_position, normalized_driver_standing, normalized_fastest_qualifying, position_quali, normalized_driver_elo, amount_of_wins, points_team, year]
# Index: []
